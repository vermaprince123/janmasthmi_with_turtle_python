# %%
# author Prince verma and Heer


import turtle

t = turtle.Turtle()
t.speed(70)
t.penup()
t.backward(300)
t.left(90)
t.forward(150)
t.pendown()
t.shape('turtle')
t.color('cyan')
wh = turtle.Screen()
wh.bgcolor('black')

# it is for H

t.forward(100)
t.right(90)
t.forward(20)
t.right(90)
t.forward(40)
t.left(90)
t.forward(30)
t.left(90)
t.forward(40)
t.right(90)
t.forward(20)
t.right(90)
t.forward(100)
t.right(90)
t.forward(20)
t.right(90)
t.forward(40)
t.left(90)
t.forward(30)
t.left(90)
t.forward(40)
t.right(90)
t.forward(20)



# it is for A
t.penup()
t.backward(90)
t.pendown()
t.right(90)
t.forward(100)
t.right(90)
t.forward(60)
t.right(90)
t.forward(100)
t.right(90)
t.forward(10)
t.right(90)
t.forward(60)
t.left(90)
t.forward(40)
t.left(90)
t.forward(60)
t.right(90)
t.forward(10)





# it is for p
t.penup()
t.backward(90)
t.pendown()
t.right(90)
t.forward(100)
t.right(90)
t.forward(60)
t.right(90)
t.forward(40)
t.right(90)
t.forward(50)
t.left(90)
t.forward(60)
t.right(90)
t.forward(10)


# it is for second p
t.penup()
t.backward(90)
t.pendown()
t.right(90)
t.forward(100)
t.right(90)
t.forward(60)
t.right(90)
t.forward(40)
t.right(90)
t.forward(50)
t.left(90)
t.forward(60)
t.right(90)
t.forward(10)


# it is for y
t.penup()
t.backward(90)
t.right(90)
t.forward(50)
t.pendown()
t.forward(50)
t.right(90)
t.forward(10)
t.right(90)
t.forward(50)
t.left(90)
t.forward(50)
t.left(90)
t.forward(50)
t.right(90)
t.forward(10)
t.right(90)
t.forward(100)
t.right(90)
t.forward(70)
t.right(90)
t.forward(10)
t.right(90)
t.forward(60)
t.left(90)
t.forward(30)
t.left(90)
t.forward(60)
t.right(90)
t.forward(10)


t.penup()
t.backward(250)
t.left(90)
t.forward(350)
t.right(90)
t.pendown()

#letter k

t.forward(100)
t.right(90)
t.forward(10)
t.right(90)
t.forward(40)
t.left(135)
t.forward(48.5)
t.right(90)
t.forward(10)
t.right(90)
t.forward(58)
t.left(90)
t.forward(58)
t.right(90)
t.forward(10)
t.right(90)
t.forward(48.5)
t.left(135)
t.forward(30)
t.right(90)
t.forward(10)

t.penup()
t.backward(90)
t.pendown()

#letter r
t.right(90)
t.forward(100)
t.right(90)
t.forward(50)
t.right(90)
t.forward(40)
t.right(90)
t.forward(40)
t.left(135)
t.forward(70.5)
t.right(90)
t.forward(10)
t.right(90)
t.forward(60.5)
t.left(135)
t.forward(50)
t.right(90)
t.forward(10)

t.penup()
t.backward(90)
t.pendown()

#letter i
t.right(90)
t.forward(100)
t.right(90)
t.forward(10)
t.right(90)
t.forward(100)
t.right(90)
t.forward(10)

t.penup()
t.backward(40)
t.pendown()

#letter s
t.right(90)
t.forward(10)
t.right(90)
t.forward(40)
t.left(90)
t.forward(40)
t.left(90)
t.forward(40)
t.right(90)
t.forward(50)
t.right(90)
t.forward(40)
t.right(90)
t.forward(10)
t.right(90)
t.forward(30)
t.left(90)
t.forward(30)
t.left(90)
t.forward(40)
t.right(90)
t.forward(60)
t.right(90)
t.forward(50)
t.right(90)
t.forward(10)

t.penup()
t.backward(10)
t.left(90)
t.backward(90)

#letter h
t.pendown()
t.right(90)
t.forward(100)
t.right(90)
t.forward(20)
t.right(90)
t.forward(40)
t.left(90)
t.forward(30)
t.left(90)
t.forward(40)
t.right(90)
t.forward(20)
t.right(90)
t.forward(100)
t.right(90)
t.forward(20)
t.right(90)
t.forward(40)
t.left(90)
t.forward(30)
t.left(90)
t.forward(40)
t.right(90)
t.forward(20)

t.penup()
t.backward(90)
t.pendown()

#letter n
t.right(90)
t.forward(100)
t.right(90)
t.forward(10)
t.right(60)
t.forward(100)
t.left(150)
t.forward(90)
t.right(90)
t.forward(10)
t.right(90)
t.forward(100)
t.right(90)
t.forward(15)
t.right(60)
t.forward(90)
t.left(150)
t.forward(80)
t.right(90)
t.forward(10)

t.penup()
t.backward(90)
t.pendown()

#letter a
t.right(90)
t.forward(100)
t.right(90)
t.forward(60)
t.right(90)
t.forward(100)
t.right(90)
t.forward(10)
t.right(90)
t.forward(60)
t.left(90)
t.forward(40)
t.left(90)
t.forward(60)
t.right(90)
t.forward(10)


t.penup()
t.right(90)
t.backward(50)
t.left(90)
t.forward(400)
t.left(90)
t.forward(100)
t.right(90)
t.forward(100)
t.pendown()


#letter j
t.right(90)
t.forward(10)
t.right(90)
t.forward(40)
t.left(90)
t.forward(90)
t.right(90)
t.forward(10)
t.right(90)
t.forward(100)
t.right(90)
t.forward(50)

t.penup()
t.backward(90)
t.pendown()

#letter a
t.right(90)
t.forward(100)
t.right(90)
t.forward(60)
t.right(90)
t.forward(100)
t.right(90)
t.forward(10)
t.right(90)
t.forward(60)
t.left(90)
t.forward(40)
t.left(90)
t.forward(60)
t.right(90)
t.forward(10)

t.penup()
t.backward(90)
t.pendown()

#letter n
t.right(90)
t.forward(100)
t.right(90)
t.forward(10)
t.right(60)
t.forward(100)
t.left(150)
t.forward(90)
t.right(90)
t.forward(10)
t.right(90)
t.forward(100)
t.right(90)
t.forward(15)
t.right(60)
t.forward(90)
t.left(150)
t.forward(80)
t.right(90)
t.forward(10)

t.penup()
t.backward(90)
t.pendown()

#letter m
t.right(90)
t.forward(100)
t.right(90)
t.forward(10)
t.right(60)
t.forward(50)
t.left(120)
t.forward(50)
t.right(60)
t.forward(10)
t.right(90)
t.forward(100)
t.right(90)
t.forward(10)
t.right(90)
t.forward(80)
t.left(150)
t.forward(50)
t.right(120)
t.forward(50)
t.left(150)
t.forward(80)
t.right(90)
t.forward(10)

t.penup()
t.backward(90)
t.pendown()

#letter a
t.right(90)
t.forward(100)
t.right(90)
t.forward(60)
t.right(90)
t.forward(100)
t.right(90)
t.forward(10)
t.right(90)
t.forward(60)
t.left(90)
t.forward(40)
t.left(90)
t.forward(60)
t.right(90)
t.forward(10)

t.penup()
t.backward(90)
t.pendown()

#letter s
t.right(90)
t.forward(10)
t.right(90)
t.forward(40)
t.left(90)
t.forward(40)
t.left(90)
t.forward(40)
t.right(90)
t.forward(50)
t.right(90)
t.forward(40)
t.right(90)
t.forward(10)
t.right(90)
t.forward(30)
t.left(90)
t.forward(30)
t.left(90)
t.forward(40)
t.right(90)
t.forward(60)
t.right(90)
t.forward(50)
t.right(90)
t.forward(10)


t.penup()
t.backward(10)
t.left(90)
t.backward(100)
t.pendown()

#letter t
t.right(90)
t.forward(90)
t.left(90)
t.forward(40)
t.right(90)
t.forward(10)
t.right(90)
t.forward(90)
t.right(90)
t.forward(10)
t.right(90)
t.forward(40)
t.left(90)
t.forward(90)
t.right(90)
t.forward(10)

t.penup()
t.backward(90)
t.pendown()

#letter a
t.right(90)
t.forward(100)
t.right(90)
t.forward(60)
t.right(90)
t.forward(100)
t.right(90)
t.forward(10)
t.right(90)
t.forward(60)
t.left(90)
t.forward(40)
t.left(90)
t.forward(60)
t.right(90)
t.forward(10)

t.penup()
t.backward(90)
t.pendown()

#letter m
t.right(90)
t.forward(100)
t.right(90)
t.forward(10)
t.right(60)
t.forward(50)
t.left(120)
t.forward(50)
t.right(60)
t.forward(10)
t.right(90)
t.forward(100)
t.right(90)
t.forward(10)
t.right(90)
t.forward(80)
t.left(150)
t.forward(50)
t.right(120)
t.forward(50)
t.left(150)
t.forward(80)
t.right(90)
t.forward(10)

t.penup()
t.backward(90)
t.pendown()


#letter i
t.right(90)
t.forward(100)
t.right(90)
t.forward(10)
t.right(90)
t.forward(100)
t.right(90)
t.forward(10)

# it is for star
t.penup()
t.forward(900)
t.pendown()
t.forward(200)
t.left(170)
t.forward(200)
